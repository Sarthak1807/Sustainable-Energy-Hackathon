# %% [markdown]
# # Descriptive, Multivariate and Statistical Analysis

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = pd.read_csv("Final_SolarData.csv")
data.head()
# Out:
#   location            date_time  solarvoltage  solarcurrent  solarenergy  \
# 0     Peru  2015-12-02 00:00:27           0.0           0.0          0.0
# 1     Peru  2015-12-02 00:01:40           0.0           0.0          0.0
# 2     Peru  2015-12-02 00:02:52           0.0           0.0          0.0
# 3     Peru  2015-12-02 00:04:05           0.0           0.0          0.0
# 4     Peru  2015-12-02 00:05:18           0.0           0.0          0.0
#
#    solarpower  batteryvoltage  batterycurrent  batterypower  load_energy1  \
# 0         0.0           98.78             0.0           0.0          0.00
# 1         0.0           98.80             0.0           0.0          0.01
# 2         0.0           98.55             0.0           0.0          0.00
# 3         0.0           98.64             0.0           0.0          0.00
# 4         0.0           98.59             0.0           0.0          0.01
#
#    ...  load_energy2  load_power2  load_current2  load_voltage2  \
# 0  ...          0.00        81.46           0.43         188.58
# 1  ...          0.01        71.66           0.38         188.51
# 2  ...          0.00        81.26           0.43         188.12
# 3  ...          0.00        87.84           0.46         188.29
# 4  ...          0.00        78.17           0.41         188.51
#
#    inverter_input_power  inverter_output_power  inverter_input_energy  \
# 0                  0.52                   0.32                  0.000
# 1                  0.52                   0.32                  0.007
# 2                  0.52                   0.32                  0.000
# 3                  0.66                   0.45                  0.021
# 4                  0.66                   0.44                  0.007
#
#    inverter_output_energy  irradiance  temperature
# 0                   0.000          15        38.44
# 1                   0.000           0        38.44
# 2                   0.007          15        38.44
# 3                   0.007           0        38.44
# 4                   0.007           0        38.44
#
# [5 rows x 23 columns]

# %%
sns.boxplot(data["irradiance"])
# Out:
# C:\Users\decos\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='irradiance'>

# %%
from scipy import stats
from scipy.stats import zscore

z_scores = stats.zscore(data["irradiance"])

abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3)
data = data[filtered_entries]

sns.boxplot(data["irradiance"]) #outliers removed
# Out:
# C:\Users\decos\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='irradiance'>

# %%
data['date_time'] = pd.to_datetime(data['date_time'])
data.head()
# Out:
#   location           date_time  solarvoltage  solarcurrent  solarenergy  \
# 0     Peru 2015-12-02 00:00:27           0.0           0.0          0.0
# 1     Peru 2015-12-02 00:01:40           0.0           0.0          0.0
# 2     Peru 2015-12-02 00:02:52           0.0           0.0          0.0
# 3     Peru 2015-12-02 00:04:05           0.0           0.0          0.0
# 4     Peru 2015-12-02 00:05:18           0.0           0.0          0.0
#
#    solarpower  batteryvoltage  batterycurrent  batterypower  load_energy1  \
# 0         0.0           98.78             0.0           0.0          0.00
# 1         0.0           98.80             0.0           0.0          0.01
# 2         0.0           98.55             0.0           0.0          0.00
# 3         0.0           98.64             0.0           0.0          0.00
# 4         0.0           98.59             0.0           0.0          0.01
#
#    ...  load_energy2  load_power2  load_current2  load_voltage2  \
# 0  ...          0.00        81.46           0.43         188.58
# 1  ...          0.01        71.66           0.38         188.51
# 2  ...          0.00        81.26           0.43         188.12
# 3  ...          0.00        87.84           0.46         188.29
# 4  ...          0.00        78.17           0.41         188.51
#
#    inverter_input_power  inverter_output_power  inverter_input_energy  \
# 0                  0.52                   0.32                  0.000
# 1                  0.52                   0.32                  0.007
# 2                  0.52                   0.32                  0.000
# 3                  0.66                   0.45                  0.021
# 4                  0.66                   0.44                  0.007
#
#    inverter_output_energy  irradiance  temperature
# 0                   0.000          15        38.44
# 1                   0.000           0        38.44
# 2                   0.007          15        38.44
# 3                   0.007           0        38.44
# 4                   0.007           0        38.44
#
# [5 rows x 23 columns]

# %%
plt.figure(figsize=(20,12))
plt.plot(data['date_time'],data['irradiance'])
plt.xticks(rotation='vertical')
# Out:
# (array([16770., 16784., 16801., 16815., 16832., 16846., 16861., 16875.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(20,12))
plt.plot(data['date_time'],data['temperature'])
plt.xticks(rotation='vertical')
# Out:
# (array([16770., 16784., 16801., 16815., 16832., 16846., 16861., 16875.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(20,12))
plt.plot(data['date_time'],data['batteryvoltage'])
plt.xticks(rotation='vertical')
# Out:
# (array([16770., 16784., 16801., 16815., 16832., 16846., 16861., 16875.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(20,12))
plt.plot(data['date_time'],data['load_power2'])
plt.xticks(rotation='vertical')
# Out:
# (array([16770., 16784., 16801., 16815., 16832., 16846., 16861., 16875.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
